# %%
import pandas as pd
import seaborn as sms

# %%
data_set = pd.read_csv("C:\\Users\\User\\Desktop\\spv\\CustomerProfileData1.csv")
data_set
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  Individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  Individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  Individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  Individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  Individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  Individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# 0       TELANGANA    500084.0       MALE   1/23/1982             M
# 1       TELANGANA    500084.0       MALE   5/10/1988             M
# 2       TELANGANA    500084.0       MALE  10/15/1987             M
# 3       TELANGANA    500084.0       MALE   9/19/1990             M
# 4       TELANGANA    500084.0       MALE   1/13/1980             M
# ...           ...         ...        ...         ...           ...
# 9995  MAHARASHTRA    400050.0       MALE  10/24/1993             M
# 9996  MAHARASHTRA    400101.0       MALE    1/3/1967             M
# 9997  MAHARASHTRA    400063.0       MALE  11/26/1989             M
# 9998  MAHARASHTRA    400060.0       MALE   7/18/1972             M
# 9999  MAHARASHTRA    400075.0       MALE  12/17/1982             M
#
#      Enrolled on             Living status  Age    Age Group Month_Year  \
# 0       8/15/2018     couple with children   39  35-40 Years     Aug-18
# 1       8/15/2018     couple with children   32  30-35 Years     Aug-18
# 2       12/7/2018     couple with children   33  30-35 Years     Dec-18
# 3       12/7/2018     couple with children   30  30-35 Years     Dec-18
# 4       8/24/2018      Single/living alone   41  40- 45Years     Aug-18
# ...           ...                      ...  ...          ...        ...
# 9995     3/4/2018     couple with children   27  25-30 Years     Mar-18
# 9996   10/16/2018  Couple without children   54  50-55 Years     Oct-18
# 9997    8/27/2019  Couple without children   31  30-35 Years     Aug-19
# 9998    6/24/2018  Couple without children   48  45-50 Years     Jun-18
# 9999    11/9/2019  Couple without children   38  35-40 Years     Nov-19
#
#       Weak Num
# 0     Weak: 33
# 1     Weak: 33
# 2     Weak: 49
# 3     Weak: 49
# 4     Weak: 34
# ...        ...
# 9995  Weak: 10
# 9996  Weak: 42
# 9997  Weak: 35
# 9998  Weak: 26
# 9999  Weak: 45
#
# [10000 rows x 15 columns]

# %%
data_set
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  Individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  Individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  Individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  Individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  Individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  Individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# 0       TELANGANA    500084.0       MALE   1/23/1982             M
# 1       TELANGANA    500084.0       MALE   5/10/1988             M
# 2       TELANGANA    500084.0       MALE  10/15/1987             M
# 3       TELANGANA    500084.0       MALE   9/19/1990             M
# 4       TELANGANA    500084.0       MALE   1/13/1980             M
# ...           ...         ...        ...         ...           ...
# 9995  MAHARASHTRA    400050.0       MALE  10/24/1993             M
# 9996  MAHARASHTRA    400101.0       MALE    1/3/1967             M
# 9997  MAHARASHTRA    400063.0       MALE  11/26/1989             M
# 9998  MAHARASHTRA    400060.0       MALE   7/18/1972             M
# 9999  MAHARASHTRA    400075.0       MALE  12/17/1982             M
#
#      Enrolled on             Living status  Age    Age Group Month_Year  \
# 0       8/15/2018     couple with children   39  35-40 Years     Aug-18
# 1       8/15/2018     couple with children   32  30-35 Years     Aug-18
# 2       12/7/2018     couple with children   33  30-35 Years     Dec-18
# 3       12/7/2018     couple with children   30  30-35 Years     Dec-18
# 4       8/24/2018      Single/living alone   41  40- 45Years     Aug-18
# ...           ...                      ...  ...          ...        ...
# 9995     3/4/2018     couple with children   27  25-30 Years     Mar-18
# 9996   10/16/2018  Couple without children   54  50-55 Years     Oct-18
# 9997    8/27/2019  Couple without children   31  30-35 Years     Aug-19
# 9998    6/24/2018  Couple without children   48  45-50 Years     Jun-18
# 9999    11/9/2019  Couple without children   38  35-40 Years     Nov-19
#
#       Weak Num
# 0     Weak: 33
# 1     Weak: 33
# 2     Weak: 49
# 3     Weak: 49
# 4     Weak: 34
# ...        ...
# 9995  Weak: 10
# 9996  Weak: 42
# 9997  Weak: 35
# 9998  Weak: 26
# 9999  Weak: 45
#
# [10000 rows x 15 columns]

# %%
data_set.head()
# Out:
#                                 Column1        Type  Status       City  \
# 0  0001F736-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 1  0001F87E-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 2  000D76D7-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 3  000D7905-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 4  002D134F-A76C-11e8-8B0C-0050568252F9  Individual  Active  Hyderabad
#
#        State  PostalCode GenderCode   BirthDate MaritalStatus Enrolled on   \
# 0  TELANGANA    500084.0       MALE   1/23/1982             M    8/15/2018
# 1  TELANGANA    500084.0       MALE   5/10/1988             M    8/15/2018
# 2  TELANGANA    500084.0       MALE  10/15/1987             M    12/7/2018
# 3  TELANGANA    500084.0       MALE   9/19/1990             M    12/7/2018
# 4  TELANGANA    500084.0       MALE   1/13/1980             M    8/24/2018
#
#           Living status  Age    Age Group Month_Year  Weak Num
# 0  couple with children   39  35-40 Years     Aug-18  Weak: 33
# 1  couple with children   32  30-35 Years     Aug-18  Weak: 33
# 2  couple with children   33  30-35 Years     Dec-18  Weak: 49
# 3  couple with children   30  30-35 Years     Dec-18  Weak: 49
# 4   Single/living alone   41  40- 45Years     Aug-18  Weak: 34

# %%
sms.countplot(x='Age Group', data=data_set)
data_set['Age Group'].value_counts()
# Out:
# 30-35 Years    2192
# 25-30 Years    1646
# 35-40 Years    1640
# 40- 45Years    1266
# 20-25 Years     860
# 45-50 Years     736
# 50-55 Years     630
# 60+ Years       614
# 55-60 Years     316
# 0-20 Years      100
# Name: Age Group, dtype: int64

# %%
data_set[data_set["Age"]>50]
# Out:
#                                    Column1        Type  Status       City  \
# 8     005A6507-FE81-11e8-BE60-0050569973AB  Individual  Active  Hyderabad
# 17    01130CBF-E692-11e9-956A-005056984FDD  Individual  Active  Hyderabad
# 21    01487B1C-97A7-11e8-A57A-0050569D5A2F  Individual  Active  Hyderabad
# 22    01487B4B-97A7-11e8-A57A-0050569D5A2F  Individual  Active  Hyderabad
# 23    01487B75-97A7-11e8-A57A-0050569D5A2F  Individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9970  043D7BD6-C224-11e9-93A2-0050569973AB  Individual  Active     Mumbai
# 9971  043D7BFB-C224-11e9-93A2-0050569973AB  Individual  Active     Mumbai
# 9973  043D7C69-C224-11e9-93A2-0050569973AB  Individual  Active     Mumbai
# 9974  043D7C89-C224-11e9-93A2-0050569973AB  Individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  Individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# 8       TELANGANA    500084.0       MALE   10/1/1959             M
# 17      TELANGANA    500084.0       MALE   8/23/1968             M
# 21      TELANGANA    500084.0       MALE   9/22/1967             M
# 22      TELANGANA    500084.0       MALE   1/21/1954             M
# 23      TELANGANA    500084.0       MALE   1/15/1958             M
# ...           ...         ...        ...         ...           ...
# 9970  MAHARASHTRA    400063.0       MALE  10/30/1968             M
# 9971  MAHARASHTRA    400054.0       MALE   9/11/1965             M
# 9973  MAHARASHTRA    400022.0       MALE   10/8/1956             M
# 9974  MAHARASHTRA    400064.0       MALE   6/13/1965             M
# 9996  MAHARASHTRA    400101.0       MALE    1/3/1967             M
#
#      Enrolled on             Living status  Age    Age Group Month_Year  \
# 8      12/13/2018  Couple without children   61    60+ Years     Dec-18
# 17      10/4/2019  Couple without children   52  50-55 Years     Oct-19
# 21       8/4/2018     couple with children   53  50-55 Years     Aug-18
# 22       8/4/2018     couple with children   67    60+ Years     Aug-18
# 23       8/4/2018     couple with children   63    60+ Years     Aug-18
# ...           ...                      ...  ...          ...        ...
# 9970    8/19/2019  Couple without children   52  50-55 Years     Aug-19
# 9971    8/19/2019  Couple without children   55  55-60 Years     Aug-19
# 9973    8/19/2019  Couple without children   64    60+ Years     Aug-19
# 9974    8/19/2019  Couple without children   55  55-60 Years     Aug-19
# 9996   10/16/2018  Couple without children   54  50-55 Years     Oct-18
#
#       Weak Num
# 8     Weak: 50
# 17    Weak: 40
# 21    Weak: 31
# 22    Weak: 31
# 23    Weak: 31
# ...        ...
# 9970  Weak: 34
# 9971  Weak: 34
# 9973  Weak: 34
# 9974  Weak: 34
# 9996  Weak: 42
#
# [1383 rows x 15 columns]

# %%
data_set["Age"]>50
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Age, Length: 10000, dtype: bool

# %%
data_set = data_set.rename(columns={"Age" : "Age(years)"})
data_set
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  Individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  Individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  Individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  Individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  Individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  Individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# 0       TELANGANA    500084.0       MALE   1/23/1982             M
# 1       TELANGANA    500084.0       MALE   5/10/1988             M
# 2       TELANGANA    500084.0       MALE  10/15/1987             M
# 3       TELANGANA    500084.0       MALE   9/19/1990             M
# 4       TELANGANA    500084.0       MALE   1/13/1980             M
# ...           ...         ...        ...         ...           ...
# 9995  MAHARASHTRA    400050.0       MALE  10/24/1993             M
# 9996  MAHARASHTRA    400101.0       MALE    1/3/1967             M
# 9997  MAHARASHTRA    400063.0       MALE  11/26/1989             M
# 9998  MAHARASHTRA    400060.0       MALE   7/18/1972             M
# 9999  MAHARASHTRA    400075.0       MALE  12/17/1982             M
#
#      Enrolled on             Living status  Age(years)    Age Group  \
# 0       8/15/2018     couple with children          39  35-40 Years
# 1       8/15/2018     couple with children          32  30-35 Years
# 2       12/7/2018     couple with children          33  30-35 Years
# 3       12/7/2018     couple with children          30  30-35 Years
# 4       8/24/2018      Single/living alone          41  40- 45Years
# ...           ...                      ...         ...          ...
# 9995     3/4/2018     couple with children          27  25-30 Years
# 9996   10/16/2018  Couple without children          54  50-55 Years
# 9997    8/27/2019  Couple without children          31  30-35 Years
# 9998    6/24/2018  Couple without children          48  45-50 Years
# 9999    11/9/2019  Couple without children          38  35-40 Years
#
#      Month_Year  Weak Num
# 0        Aug-18  Weak: 33
# 1        Aug-18  Weak: 33
# 2        Dec-18  Weak: 49
# 3        Dec-18  Weak: 49
# 4        Aug-18  Weak: 34
# ...         ...       ...
# 9995     Mar-18  Weak: 10
# 9996     Oct-18  Weak: 42
# 9997     Aug-19  Weak: 35
# 9998     Jun-18  Weak: 26
# 9999     Nov-19  Weak: 45
#
# [10000 rows x 15 columns]

# %%
data_set.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
data_set.drop_duplicates(inplace=True)
data_set
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  Individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  Individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  Individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  Individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  Individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  Individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# 0       TELANGANA    500084.0       MALE   1/23/1982             M
# 1       TELANGANA    500084.0       MALE   5/10/1988             M
# 2       TELANGANA    500084.0       MALE  10/15/1987             M
# 3       TELANGANA    500084.0       MALE   9/19/1990             M
# 4       TELANGANA    500084.0       MALE   1/13/1980             M
# ...           ...         ...        ...         ...           ...
# 9995  MAHARASHTRA    400050.0       MALE  10/24/1993             M
# 9996  MAHARASHTRA    400101.0       MALE    1/3/1967             M
# 9997  MAHARASHTRA    400063.0       MALE  11/26/1989             M
# 9998  MAHARASHTRA    400060.0       MALE   7/18/1972             M
# 9999  MAHARASHTRA    400075.0       MALE  12/17/1982             M
#
#      Enrolled on             Living status  Age(years)    Age Group  \
# 0       8/15/2018     couple with children          39  35-40 Years
# 1       8/15/2018     couple with children          32  30-35 Years
# 2       12/7/2018     couple with children          33  30-35 Years
# 3       12/7/2018     couple with children          30  30-35 Years
# 4       8/24/2018      Single/living alone          41  40- 45Years
# ...           ...                      ...         ...          ...
# 9995     3/4/2018     couple with children          27  25-30 Years
# 9996   10/16/2018  Couple without children          54  50-55 Years
# 9997    8/27/2019  Couple without children          31  30-35 Years
# 9998    6/24/2018  Couple without children          48  45-50 Years
# 9999    11/9/2019  Couple without children          38  35-40 Years
#
#      Month_Year  Weak Num
# 0        Aug-18  Weak: 33
# 1        Aug-18  Weak: 33
# 2        Dec-18  Weak: 49
# 3        Dec-18  Weak: 49
# 4        Aug-18  Weak: 34
# ...         ...       ...
# 9995     Mar-18  Weak: 10
# 9996     Oct-18  Weak: 42
# 9997     Aug-19  Weak: 35
# 9998     Jun-18  Weak: 26
# 9999     Nov-19  Weak: 45
#
# [10000 rows x 15 columns]

# %%
#Manipulating Data
data_set["City"]= data_set["City"].str.lower()
data_set
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  Individual  Active  hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  Individual  Active  hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  Individual  Active  hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  Individual  Active  hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  Individual  Active  hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  Individual  Active     mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  Individual  Active     mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  Individual  Active     mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  Individual  Active     mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  Individual  Active     mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# 0       TELANGANA    500084.0       MALE   1/23/1982             M
# 1       TELANGANA    500084.0       MALE   5/10/1988             M
# 2       TELANGANA    500084.0       MALE  10/15/1987             M
# 3       TELANGANA    500084.0       MALE   9/19/1990             M
# 4       TELANGANA    500084.0       MALE   1/13/1980             M
# ...           ...         ...        ...         ...           ...
# 9995  MAHARASHTRA    400050.0       MALE  10/24/1993             M
# 9996  MAHARASHTRA    400101.0       MALE    1/3/1967             M
# 9997  MAHARASHTRA    400063.0       MALE  11/26/1989             M
# 9998  MAHARASHTRA    400060.0       MALE   7/18/1972             M
# 9999  MAHARASHTRA    400075.0       MALE  12/17/1982             M
#
#      Enrolled on             Living status  Age(years)    Age Group  \
# 0       8/15/2018     couple with children          39  35-40 Years
# 1       8/15/2018     couple with children          32  30-35 Years
# 2       12/7/2018     couple with children          33  30-35 Years
# 3       12/7/2018     couple with children          30  30-35 Years
# 4       8/24/2018      Single/living alone          41  40- 45Years
# ...           ...                      ...         ...          ...
# 9995     3/4/2018     couple with children          27  25-30 Years
# 9996   10/16/2018  Couple without children          54  50-55 Years
# 9997    8/27/2019  Couple without children          31  30-35 Years
# 9998    6/24/2018  Couple without children          48  45-50 Years
# 9999    11/9/2019  Couple without children          38  35-40 Years
#
#      Month_Year  Weak Num
# 0        Aug-18  Weak: 33
# 1        Aug-18  Weak: 33
# 2        Dec-18  Weak: 49
# 3        Dec-18  Weak: 49
# 4        Aug-18  Weak: 34
# ...         ...       ...
# 9995     Mar-18  Weak: 10
# 9996     Oct-18  Weak: 42
# 9997     Aug-19  Weak: 35
# 9998     Jun-18  Weak: 26
# 9999     Nov-19  Weak: 45
#
# [10000 rows x 15 columns]

# %%
sms.countplot(x='Age', data=data_set, hue='Age Group')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-6dd8d76ae600> in <module>
# ----> 1 sms.countplot(x='Age', data=data_set, hue='Age Group')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3583         raise ValueError("Cannot pass values for both `x` and `y`")
#    3584
# -> 3585     plotter = _CountPlotter(
#    3586         x, y, hue, data, order, hue_order,
#    3587         estimator, ci, n_boot, units, seed,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Age'

# %%
# series is a 1-D array

Customers_name = pd.Series(["Razan Sarker", "Shama Saha", "Mim", "Nag","Imran"])
Customers_country = pd.Series(["Bangladesh", "Uganda", "Nigeria", "Somalia", "Zimbabwe"])

# %%
Customers_name
# Out:
# 0    Razan Sarker
# 1      Shama Saha
# 2             Mim
# 3             Nag
# 4           Imran
# dtype: object

# %%
Customers_country
# Out:
# 0    Bangladesh
# 1        Uganda
# 2       Nigeria
# 3       Somalia
# 4      Zimbabwe
# dtype: object

# %%
Customers_data = pd.DataFrame({"Name":Customers_name, "Country":Customers_country})
Customers_data
# Out:
#            Name     Country
# 0  Razan Sarker  Bangladesh
# 1    Shama Saha      Uganda
# 2           Mim     Nigeria
# 3           Nag     Somalia
# 4         Imran    Zimbabwe

# %%
data_set.dtypes

# %%
data_set.columns

# %%
data_set.index

# %%
data_set.describe()

# %%
data_set.info()

# %%
data_set.mean()

# %%
data_set.groupby(["State"]).mean()

# %%
Customers_wage = pd.Series([100.9, 55, 120.5])
Customers_wage.mean()

# %%
data_set["Age"].sum()

# %%
pd.crosstab(Customers_name, Customers_country)

# %%
# plotting Data 

data_set["PostalCode"].plot()

# %%
data_set["PostalCode"].hist()

# %%
data_set["Age"].plot()

# %%
data_set["Age"].hist()

# %%
df_missing = pd.read_csv("C:\\Users\\User\\Desktop\\spv\\CustomerProfileData1-missing.csv")
df_missing
# Out:
#                                    Column1        Type    Status  \
# 0     00005DCC-4E51-41A5-91C5-6635B24C7D17    Business  InActive
# 1     0001F49E-9FE7-11e8-9E9C-00505682069A  Individual    Active
# 2     0001F4A2-9FE7-11e8-9E9C-00505682069A  Individual    Active
# 3     0001F4CD-9FE7-11e8-9E9C-00505682069A  Individual    Active
# 4     0001F4DE-9FE7-11e8-9E9C-00505682069A  Individual    Active
# ...                                    ...         ...       ...
# 9995  0476D7F9-6B51-11e8-B278-0050569D3164  Individual    Active
# 9996  0476D7FD-6B51-11e8-B278-0050569D3164  Individual    Active
# 9997  0476D812-6B51-11e8-B278-0050569D3164  Individual    Active
# 9998  0476D81A-6B51-11e8-B278-0050569D3164  Individual    Active
# 9999  0476D821-6B51-11e8-B278-0050569D3164  Individual    Active
#
#                 City           State  PostalCode GenderCode  BirthDate  \
# 0                NaN             NaN    500024.0       MALE  12-Aug-18
# 1             Valsad         GUJARAT    396001.0       MALE   2-Nov-92
# 2       Secunderabad       TELANGANA    500011.0     FEMALE  25-Nov-88
# 3           Nalgonda       TELANGANA    508101.0       MALE  13-Jun-83
# 4          Hyderabad       TELANGANA    500028.0       MALE  13-Jul-75
# ...              ...             ...         ...        ...        ...
# 9995       Hyderabad       Telangana    500032.0       MALE   3-Jul-97
# 9996       Hyderabad  ANDHRA PRADESH    500002.0       MALE  24-May-80
# 9997    Secunderabad  ANDHRA PRADESH    500080.0     FEMALE  22-Nov-84
# 9998  Hyderabad City  ANDHRA PRADESH    500081.0     FEMALE  14-Jul-94
# 9999    Secunderabad  ANDHRA PRADESH    500090.0       MALE   9-Jul-77
#
#      MaritalStatus Enrolled on             Living status
# 0                U    12-Aug-18     couple with children
# 1                M    14-Aug-18     couple with children
# 2                M    14-Aug-18     couple with children
# 3                M    14-Aug-18     couple with children
# 4                M    14-Aug-18     couple with children
# ...            ...          ...                      ...
# 9995             M     9-Jun-18  Couple without children
# 9996             M     9-Jun-18  Couple without children
# 9997             M     9-Jun-18  Couple without children
# 9998             M     9-Jun-18  Couple without children
# 9999             M     9-Jun-18  Couple without children
#
# [10000 rows x 11 columns]

# %%
df_missing.dropna(inplace=True)
df_missing

# %%
df_missing_shuffled = df_missing.sample(frac=1)
df_missing_shuffled

# %%
df_missing_shuffled.sample(frac=.3)

# %%
df_missing_shuffled.reset_index(inplace=True)
df_missing_shuffled

# %%
df_missing.loc[[8,9,654,34]]

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#easy may
y = [10,20,30,40,50,60]
x = [11,12,13,14,15,16]
plt.plot(x,y)

# %%
data_miss = pd.read_csv("C:\\Users\\User\\Desktop\\spv\\student.csv")
data_miss
# Out:
#    Serial_No            ID                Name  Age  Cgpa     Country
# 0          1  191-15-12966  Razan Sarker Santa   21  3.40  Bangladesh
# 1          2  191-15-12973          Shama Saha   22  3.23  Bangladesh
# 2          3  191-15-12974                 Mim   22  3.59  Bangladesh
# 3          4  192-15-12847        Kajol Biswas   20  3.44  Bangladesh
# 4          5  192-15-12857            Nila Roy   21  4.00  Bangladesh
# 5          6  192-15-12867         Pollobi Roy   21  3.95  Bangladesh
# 6          7  192-15-12877               Sagor   22  3.67         USA
# 7          8  192-15-12887               Sakib   23  3.71  Bangladesh
# 8          9  183-15-12897              Shihab   24  3.55  Bangladesh
# 9         10  192-15-12810  Kaniz fatema panna   20  3.21  Bangladesh
